# %%
from getwai import *
import os
import argparse
import subprocess
import threading
import signal
import time

# %%
outfile = 'rocksdb'
script = ''
nvme = subprocess.Popen('./nvmesnoop.py -o {}.nvme.csv'.format(outfile).split())
ycsb = subprocess.Popen(ycsb_run, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, universal_newlines=True)
